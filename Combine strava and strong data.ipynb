# %% [markdown]
# # Import the necessery modules

# %%
import pandas as pd

# %% [markdown]
# # Taking a glance at the datasets
# Import both the strava and the strong data in a dataframe so we can take a closer look

# %%
dfstrava= pd.read_csv('strava_data.txt')
dfstrava.head()
# Out:
#            id            start_date            name  distance  moving_time  \
# 0  1106056853  2017-07-28T18:10:44Z     Zomaar bike   33529.3         8510
# 1  1188348699  2017-09-17T13:09:29Z  Afternoon Ride    8421.9         1706
# 2  1189136755  2017-09-17T18:13:56Z    Evening Ride    8744.8         2162
# 3  2286729315  2018-07-27T18:06:55Z    Evening Ride   35863.2         8840
# 4  2565205233  2019-04-13T14:22:06Z  Afternoon Ride    3687.5         1442
#
#    type  average_heartrate  max_heartrate  average_speed  max_speed  \
# 0  Ride                  6              7          3.940       12.3
# 1  Ride                  6              7          4.937       10.1
# 2  Ride                  6              7          4.045       11.9
# 3  Ride                  6              7          4.057       10.4
# 4   Run                  6              7          2.557        4.2
#
#    total_elevation_gain          start_latlng            end_latlng  \
# ...

# %%
dfstrong = pd.read_csv('strong.csv')
dfstrong.head()
# Out:
#                   Date      Workout Name Exercise Name  Set Order  Weight  \
# 0  2016-03-07 21:34:52  Back Stronglifts  Lat Pulldown          1    70.0
# 1  2016-03-07 21:34:52  Back Stronglifts  Lat Pulldown          2    70.0
# 2  2016-03-07 21:34:52  Back Stronglifts  Lat Pulldown          3    90.0
# 3  2016-03-07 21:34:52  Back Stronglifts  Lat Pulldown          4    90.0
# 4  2016-03-07 21:34:52  Back Stronglifts  Lat Pulldown          5    90.0
#
#    Reps  Distance  Seconds Notes Workout Notes  RPE
# 0     5       0.0        0   NaN           NaN  NaN
# 1     5       0.0        0   NaN           NaN  NaN
# 2     5       0.0        0   NaN           NaN  NaN
# 3     5       0.0        0   NaN           NaN  NaN
# 4     5       0.0        0   NaN           NaN  NaN

# %% [markdown]
# # Manipulating the dataframes

# %% [markdown]
# Adding a column with the source

# %%
dfstrong_raw['Source'] = 'strong'
dfstrong_raw.tail()
# Out:
#                      Date     Workout Name       Exercise Name  Set Order  \
# 2112  2020-03-26 23:30:32  Evening Workout          Jump Rope           1
# 2113  2020-03-26 23:30:32  Evening Workout            Ab Wheel          1
# 2114  2020-03-26 23:30:32  Evening Workout            Ab Wheel          2
# 2115  2020-03-26 23:30:32  Evening Workout  Squat (Bodyweight)          1
# 2116  2020-03-26 23:30:32  Evening Workout  Squat (Bodyweight)          2
#
#       Weight  Reps  Distance  Seconds Notes Workout Notes  RPE  Source
# 2112     0.0     0       0.0      300   NaN           NaN  NaN  strong
# 2113     0.0    10       0.0        0   NaN           NaN  NaN  strong
# 2114     0.0    10       0.0        0   NaN           NaN  NaN  strong
# 2115     0.0    40       0.0        0   NaN           NaN  NaN  strong
# 2116     0.0    10       0.0        0   NaN           NaN  NaN  strong

# %% [markdown]
# We're going to only use the columns we want use from the strava file and name those columns so that they match the ones in the strong file

# %%
dfstrava = pd.read_csv('strava_data.txt', header=0, usecols=['start_date', 'name', 'distance', 'moving_time', 'type'])
dfstrava.columns =['Date', 'Workout Name', 'Distance', 'Seconds', 'Exercise Name']
dfstrava['Source'] = 'strava'
dfstrava.head()
# Out:
#                    Date    Workout Name  Distance  Seconds Exercise Name  \
# 0  2017-07-28T18:10:44Z     Zomaar bike   33529.3     8510          Ride
# 1  2017-09-17T13:09:29Z  Afternoon Ride    8421.9     1706          Ride
# 2  2017-09-17T18:13:56Z    Evening Ride    8744.8     2162          Ride
# 3  2018-07-27T18:06:55Z    Evening Ride   35863.2     8840          Ride
# 4  2019-04-13T14:22:06Z  Afternoon Ride    3687.5     1442           Run
#
#    Source
# 0  strava
# 1  strava
# 2  strava
# 3  strava
# 4  strava

# %% [markdown]
# Changing the exercise with name from "Ride" to "Cycling" so that they match the strong name

# %%
dfstrava = dfstrava.replace('Ride', 'Cycling')

# %% [markdown]
# Changing the distances in the strong data file to metres from km, so we can compare apples to apples

# %%
dfstrong_raw.Distance = dfstrong_raw.Distance*1000
dfstrong_raw.tail(70)
# Out:
#                      Date     Workout Name       Exercise Name  Set Order  \
# 2047  2020-02-26 12:52:26   Midday Workout             Cycling          1
# 2048  2020-02-26 12:52:26   Midday Workout               Plank          1
# 2049  2020-02-26 12:52:26   Midday Workout               Plank          2
# 2050  2020-02-26 12:52:26   Midday Workout             Pull Up          1
# 2051  2020-02-26 12:52:26   Midday Workout             Pull Up          2
# ...                   ...              ...                 ...        ...
# 2112  2020-03-26 23:30:32  Evening Workout          Jump Rope           1
# 2113  2020-03-26 23:30:32  Evening Workout            Ab Wheel          1
# 2114  2020-03-26 23:30:32  Evening Workout            Ab Wheel          2
# 2115  2020-03-26 23:30:32  Evening Workout  Squat (Bodyweight)          1
# 2116  2020-03-26 23:30:32  Evening Workout  Squat (Bodyweight)          2
#
#       Weight  Reps  Distance  Seconds    Notes Workout Notes  RPE  Source
# ...

# %% [markdown]
# Adding the two dataframes into one

# %%
dfcombo = dfstrong_raw.append(dfstrava, 'sort=True')
dfcombo
# Out:
# /Users/glencoppens/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#                       Date  Distance Exercise Name Notes  RPE  Reps  Seconds  \
# 0      2016-03-07 21:34:52       0.0  Lat Pulldown   NaN  NaN   5.0        0
# 1      2016-03-07 21:34:52       0.0  Lat Pulldown   NaN  NaN   5.0        0
# 2      2016-03-07 21:34:52       0.0  Lat Pulldown   NaN  NaN   5.0        0
# 3      2016-03-07 21:34:52       0.0  Lat Pulldown   NaN  NaN   5.0        0
# 4      2016-03-07 21:34:52       0.0  Lat Pulldown   NaN  NaN   5.0        0
# ...                    ...       ...           ...   ...  ...   ...      ...
# ...

# %% [markdown]
# Write the dataframe as a csv in the right directory so further exploration in tableau can be done

# %%
dfcombo.to_csv('/Users/glencoppens/My Tableau Repository/Datasources/strongstravacombo.csv')
